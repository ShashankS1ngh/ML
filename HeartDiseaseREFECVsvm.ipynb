# %% [markdown]
# <a href="https://colab.research.google.com/github/ShashankS1ngh/ML/blob/main/HeartDiseaseREFECVsvm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.display import display, HTML, Javascript

color_map = ['#8A0030', '#BA1141']

prompt = color_map[-1]
main_color = color_map[0]
strong_main_color = color_map[1]
custom_colors = [strong_main_color, main_color]

css_file = '''
div #notebook {
background-color: white;
line-height: 20px;
}

#notebook-container {
# %s
margin-top: 2em;
padding-top: 2em;
border-top: 4px solid %s;
-webkit-box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5);
    box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5);
}

div .input {
margin-bottom: 1em;
}

.rendered_html h1, .rendered_html h2, .rendered_html h3, .rendered_html h4, .rendered_html h5, .rendered_html h6 {
color: %s;
font-weight: 600;
}

div.input_area {
border: none;
    background-color: %s;
    border-top: 2px solid %s;
}

div.input_prompt {
color: %s;
}

div.output_prompt {
color: %s; 
}

div.cell.selected:before, div.cell.selected.jupyter-soft-selected:before {
background: %s;
}

div.cell.selected, div.cell.selected.jupyter-soft-selected {
    border-color: %s;
}

.edit_mode div.cell.selected:before {
background: %s;
}

.edit_mode div.cell.selected {
border-color: %s;

}
'''

def to_rgb(h): 
    return tuple(int(h[i:i+2], 16) for i in [0, 2, 4])

main_color_rgba = 'rgba(%s, %s, %s, 0.1)' % (to_rgb(main_color[1:]))
open('notebook.css', 'w').write(css_file % ('width: 95%;', main_color, main_color, main_color_rgba, main_color,  main_color, prompt, main_color, main_color, main_color, main_color))

def nb(): 
    return HTML("<style>" + open("notebook.css", "r").read() + "</style>")
nb()
# Out:
# <style>
# div #notebook {
# background-color: white;
# line-height: 20px;
# }
#
# #notebook-container {
# width: 95%;
# margin-top: 2em;
# padding-top: 2em;
# border-top: 4px solid #8A0030;
# -webkit-box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5);
#     box-shadow: 0px 0px 8px 2px rgba(224, 212, 226, 0.5);
# }
#
# div .input {
# margin-bottom: 1em;
# }
#
# .rendered_html h1, .rendered_html h2, .rendered_html h3, .rendered_html h4, .rendered_html h5, .rendered_html h6 {
# color: #8A0030;
# font-weight: 600;
# }
#
# div.input_area {
# border: none;
#     background-color: rgba(138, 0, 48, 0.1);
#     border-top: 2px solid #8A0030;
# }
#
# div.input_prompt {
# color: #8A0030;
# }
#
# div.output_prompt {
# color: #BA1141;
# }
#
# div.cell.selected:before, div.cell.selected.jupyter-soft-selected:before {
# background: #8A0030;
# }
#
# div.cell.selected, div.cell.selected.jupyter-soft-selected {
#     border-color: #8A0030;
# }
#
# .edit_mode div.cell.selected:before {
# background: #8A0030;
# }
#
# .edit_mode div.cell.selected {
# border-color: #8A0030;
#
# }
# </style>

# %%
# --- Importing Libraries ---
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
import yellowbrick
import pickle

from matplotlib.collections import PathCollection
from statsmodels.graphics.gofplots import qqplot
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.metrics import classification_report, accuracy_score
from xgboost import XGBClassifier
from yellowbrick.classifier import PrecisionRecallCurve, ROCAUC, ConfusionMatrix
from yellowbrick.style import set_palette
from yellowbrick.model_selection import LearningCurve, FeatureImportances
from yellowbrick.contrib.wrapper import wrap

# --- Libraries Settings ---
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.dpi']=100
set_palette('dark')

# %%
red_grad = ['#FF0000', '#BF0000', '#800000', '#400000', '#000000']
pink_grad = ['#8A0030', '#BA1141', '#FF5C8A', '#FF99B9', '#FFDEEB']
purple_grad = ['#4C0028', '#7F0043', '#8E004C', '#A80059', '#C10067']
color_mix = ['#F38BB2', '#FFB9CF', '#FFD7D7', '#F17881', '#E7525B']
black_grad = ['#100C07', '#3E3B39', '#6D6A6A', '#9B9A9C', '#CAC9CD']

# %%
def Heart_Disease_data(set_data):
  housing_path="https://raw.githubusercontent.com/ShashankS1ngh/ML/main/DATASETS/"
  csv_path=os.path.join(housing_path,set_data)
  return pd.read_csv(csv_path)

# %%
df= Heart_Disease_data("heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
print(df)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
df.select_dtypes(exclude='object').describe().T.style.background_gradient(cmap='PuRd').set_properties(**{'font-family': 'Segoe UI'})
# Out:
# <style type="text/css">
# #T_3ada5_row0_col0, #T_3ada5_row1_col0, #T_3ada5_row1_col1, #T_3ada5_row1_col2, #T_3ada5_row1_col3, #T_3ada5_row1_col4, #T_3ada5_row1_col6, #T_3ada5_row1_col7, #T_3ada5_row2_col0, #T_3ada5_row2_col1, #T_3ada5_row2_col3, #T_3ada5_row2_col4, #T_3ada5_row2_col7, #T_3ada5_row3_col0, #T_3ada5_row4_col0, #T_3ada5_row5_col0, #T_3ada5_row5_col1, #T_3ada5_row5_col2, #T_3ada5_row5_col3, #T_3ada5_row5_col4, #T_3ada5_row5_col5, #T_3ada5_row5_col6, #T_3ada5_row5_col7, #T_3ada5_row6_col0, #T_3ada5_row6_col1, #T_3ada5_row6_col2, #T_3ada5_row6_col3, #T_3ada5_row6_col4, #T_3ada5_row6_col6, #T_3ada5_row6_col7, #T_3ada5_row7_col0, #T_3ada5_row8_col0, #T_3ada5_row8_col1, #T_3ada5_row8_col2, #T_3ada5_row8_col3, #T_3ada5_row8_col4, #T_3ada5_row8_col5, #T_3ada5_row8_col6, #T_3ada5_row8_col7, #T_3ada5_row9_col0, #T_3ada5_row9_col1, #T_3ada5_row9_col3, #T_3ada5_row9_col4, #T_3ada5_row9_col5, #T_3ada5_row10_col0, #T_3ada5_row10_col3, #T_3ada5_row10_col7, #T_3ada5_row11_col0, #T_3ada5_row11_col1, #T_3ada5_row11_col3, #T_3ada5_row11_col4, #T_3ada5_row11_col5, #T_3ada5_row11_col6, #T_3ada5_row12_col0, #T_3ada5_row12_col3, #T_3ada5_row12_col7, #T_3ada5_row13_col0, #T_3ada5_row13_col1, #T_3ada5_row13_col2, #T_3ada5_row13_col3, #T_3ada5_row13_col4, #T_3ada5_row13_col6, #T_3ada5_row13_col7 {
#   background-color: #f7f4f9;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3ada5_row0_col1, #T_3ada5_row0_col6 {
#   background-color: #d9c3df;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3ada5_row0_col2 {
#   background-color: #e0d3e8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3ada5_row0_col3, #T_3ada5_row0_col4 {
#   background-color: #d7c0de;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3ada5_row0_col5 {
#   background-color: #d7bfdd;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3ada5_row0_col7 {
#   background-color: #e6deee;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3ada5_row1_col5, #T_3ada5_row2_col5, #T_3ada5_row2_col6, #T_3ada5_row6_col5, #T_3ada5_row9_col6, #T_3ada5_row10_col1, #T_3ada5_row10_col2, #T_3ada5_row10_col4, #T_3ada5_row10_col5, #T_3ada5_row10_col6, #T_3ada5_row11_col7, #T_3ada5_row12_col2, #T_3ada5_row13_col5 {
#   background-color: #f6f3f9;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3ada5_row2_col2, #T_3ada5_row9_col2, #T_3ada5_row11_col2 {
#   background-color: #f5f2f8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3ada5_row3_col1 {
#   background-color: #e155a6;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row3_col2 {
#   background-color: #cda0cd;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_3ada5_row3_col3 {
#   background-color: #cf1358;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row3_col4 {
#   background-color: #e3449b;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row3_col5 {
#   background-color: #e251a3;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row3_col6 {
#   background-color: #e060ad;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row3_col7 {
#   background-color: #cb9bca;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row4_col1, #T_3ada5_row4_col2, #T_3ada5_row4_col3, #T_3ada5_row4_col4, #T_3ada5_row4_col5, #T_3ada5_row4_col6, #T_3ada5_row4_col7 {
#   background-color: #67001f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row7_col1 {
#   background-color: #e6318f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row7_col2 {
#   background-color: #d57aba;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row7_col3 {
#   background-color: #e3469c;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row7_col4 {
#   background-color: #e72989;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row7_col5 {
#   background-color: #e52786;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row7_col6 {
#   background-color: #e63390;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row7_col7 {
#   background-color: #cb99ca;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_3ada5_row9_col7, #T_3ada5_row12_col1, #T_3ada5_row12_col4, #T_3ada5_row12_col5, #T_3ada5_row12_col6 {
#   background-color: #f6f3f8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_3ada5_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ada5_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_3ada5_row0_col0" class="data row0 col0" >1025.000000</td>
#       <td id="T_3ada5_row0_col1" class="data row0 col1" >54.434146</td>
#       <td id="T_3ada5_row0_col2" class="data row0 col2" >9.072290</td>
#       <td id="T_3ada5_row0_col3" class="data row0 col3" >29.000000</td>
#       <td id="T_3ada5_row0_col4" class="data row0 col4" >48.000000</td>
#       <td id="T_3ada5_row0_col5" class="data row0 col5" >56.000000</td>
#       <td id="T_3ada5_row0_col6" class="data row0 col6" >61.000000</td>
#       <td id="T_3ada5_row0_col7" class="data row0 col7" >77.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ada5_level0_row1" class="row_heading level0 row1" >sex</th>
#       <td id="T_3ada5_row1_col0" class="data row1 col0" >1025.000000</td>
#       <td id="T_3ada5_row1_col1" class="data row1 col1" >0.695610</td>
#       <td id="T_3ada5_row1_col2" class="data row1 col2" >0.460373</td>
#       <td id="T_3ada5_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_3ada5_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_3ada5_row1_col5" class="data row1 col5" >1.000000</td>
#       <td id="T_3ada5_row1_col6" class="data row1 col6" >1.000000</td>
#       <td id="T_3ada5_row1_col7" class="data row1 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ada5_level0_row2" class="row_heading level0 row2" >cp</th>
#       <td id="T_3ada5_row2_col0" class="data row2 col0" >1025.000000</td>
#       <td id="T_3ada5_row2_col1" class="data row2 col1" >0.942439</td>
#       <td id="T_3ada5_row2_col2" class="data row2 col2" >1.029641</td>
#       <td id="T_3ada5_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_3ada5_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_3ada5_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_3ada5_row2_col6" class="data row2 col6" >2.000000</td>
#       <td id="T_3ada5_row2_col7" class="data row2 col7" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ada5_level0_row3" class="row_heading level0 row3" >trestbps</th>
#       <td id="T_3ada5_row3_col0" class="data row3 col0" >1025.000000</td>
#       <td id="T_3ada5_row3_col1" class="data row3 col1" >131.611707</td>
#       <td id="T_3ada5_row3_col2" class="data row3 col2" >17.516718</td>
#       <td id="T_3ada5_row3_col3" class="data row3 col3" >94.000000</td>
#       <td id="T_3ada5_row3_col4" class="data row3 col4" >120.000000</td>
#       <td id="T_3ada5_row3_col5" class="data row3 col5" >130.000000</td>
#       <td id="T_3ada5_row3_col6" class="data row3 col6" >140.000000</td>
#       <td id="T_3ada5_row3_col7" class="data row3 col7" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3ada5_level0_row4" class="row_heading level0 row4" >chol</th>
#       <td id="T_3ada5_row4_col0" class="data row4 col0" >1025.000000</td>
#       <td id="T_3ada5_row4_col1" class="data row4 col1" >246.000000</td>
#       <td id="T_3ada5_row4_col2" class="data row4 col2" >51.592510</td>
#       <td id="T_3ada5_row4_col3" class="data row4 col3" >126.000000</td>
#       <td id="T_3ada5_row4_col4" class="data row4 col4" >211.000000</td>
#       <td id="T_3ada5_row4_col5" class="data row4 col5" >240.000000</td>
#       <td id="T_3ada5_row4_col6" class="data row4 col6" >275.000000</td>
#       <td id="T_3ada5_row4_col7" class="data row4 col7

# %%
# --- Correlation Map (Heatmap) ---
plt.figure(figsize=(14, 9))
sns.heatmap(df.corr(), annot=True, cmap='Reds', linewidths=0.1)
plt.suptitle('Correlation Map of Numerical Variables', fontweight='heavy', 
             x=0.29, y=1.02, ha='left', fontsize='16', fontfamily='sans-serif', 
             color=black_grad[0])
plt.title('Resting blood pressure, cholestoral, and "oldpeak" have moderate relationship with age.', 
          fontsize='10', fontfamily='sans-serif', loc='left', color=black_grad[1])
plt.tight_layout(rect=[0, 0.04, 1, 1.01])

# %%
cp = pd.get_dummies(df['cp'], prefix='cp')
thal = pd.get_dummies(df['thal'], prefix='thal')
slope = pd.get_dummies(df['slope'], prefix='slope')

frames = [df, cp, thal, slope]
df = pd.concat(frames, axis = 1)

# %%
from sklearn.feature_selection import RFE, RFECV, SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from statsmodels.tools import add_constant

# %%
data_frame = Heart_Disease_data("heart.csv")
df1 = pd.DataFrame(data_frame)

# %%
df1.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
rfc = RandomForestClassifier()
rfecv = RFECV(estimator = rfc, step = 1, cv = StratifiedKFold(10), scoring = 'r2',verbose=1)
X_components=df1.columns
X=df1[X_components]
y=df.target
print(X.shape)
print(y.shape)

rfecv.fit(X, y)
# Out:
# (1025, 14)
# (1025,)
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# RFECV(cv=StratifiedKFold(n_splits=10, random_state=None, shuffle=False),
#       estimator=RandomForestClassifier(), scoring='r2', verbose=1)

# %%
X.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
X_components=df1.columns
X=df1[X_components]
rfecv_array = [True, True, False,True,False,False,True,False,True,True,True,True,True,True]
res = [i for i, val in enumerate(rfecv_array) if not val]
X.drop(X.columns[res], axis=1, inplace=True)

# %%
df.head().style.background_gradient(cmap='Reds').hide_index().set_properties(**{'font-family': 'Segoe UI'})
# Out:
# <style type="text/css">
# #T_0da74_row0_col0, #T_0da74_row0_col2, #T_0da74_row0_col3, #T_0da74_row0_col5, #T_0da74_row0_col8, #T_0da74_row0_col13, #T_0da74_row0_col14, #T_0da74_row0_col15, #T_0da74_row0_col16, #T_0da74_row0_col17, #T_0da74_row0_col18, #T_0da74_row0_col19, #T_0da74_row0_col20, #T_0da74_row0_col22, #T_0da74_row0_col23, #T_0da74_row1_col2, #T_0da74_row1_col6, #T_0da74_row1_col10, #T_0da74_row1_col11, #T_0da74_row1_col13, #T_0da74_row1_col14, #T_0da74_row1_col15, #T_0da74_row1_col16, #T_0da74_row1_col17, #T_0da74_row1_col18, #T_0da74_row1_col19, #T_0da74_row1_col20, #T_0da74_row1_col23, #T_0da74_row1_col24, #T_0da74_row2_col2, #T_0da74_row2_col4, #T_0da74_row2_col5, #T_0da74_row2_col10, #T_0da74_row2_col11, #T_0da74_row2_col13, #T_0da74_row2_col14, #T_0da74_row2_col15, #T_0da74_row2_col16, #T_0da74_row2_col17, #T_0da74_row2_col18, #T_0da74_row2_col19, #T_0da74_row2_col20, #T_0da74_row2_col23, #T_0da74_row2_col24, #T_0da74_row3_col2, #T_0da74_row3_col5, #T_0da74_row3_col8, #T_0da74_row3_col9, #T_0da74_row3_col13, #T_0da74_row3_col14, #T_0da74_row3_col15, #T_0da74_row3_col16, #T_0da74_row3_col17, #T_0da74_row3_col18, #T_0da74_row3_col19, #T_0da74_row3_col20, #T_0da74_row3_col22, #T_0da74_row3_col23, #T_0da74_row4_col1, #T_0da74_row4_col2, #T_0da74_row4_col7, #T_0da74_row4_col8, #T_0da74_row4_col12, #T_0da74_row4_col13, #T_0da74_row4_col14, #T_0da74_row4_col15, #T_0da74_row4_col16, #T_0da74_row4_col17, #T_0da74_row4_col18, #T_0da74_row4_col19, #T_0da74_row4_col21, #T_0da74_row4_col22, #T_0da74_row4_col24 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0da74_row0_col1, #T_0da74_row0_col6, #T_0da74_row0_col7, #T_0da74_row0_col10, #T_0da74_row0_col12, #T_0da74_row0_col21, #T_0da74_row0_col24, #T_0da74_row1_col1, #T_0da74_row1_col5, #T_0da74_row1_col8, #T_0da74_row1_col9, #T_0da74_row1_col12, #T_0da74_row1_col21, #T_0da74_row1_col22, #T_0da74_row2_col0, #T_0da74_row2_col1, #T_0da74_row2_col6, #T_0da74_row2_col8, #T_0da74_row2_col12, #T_0da74_row2_col21, #T_0da74_row2_col22, #T_0da74_row3_col1, #T_0da74_row3_col3, #T_0da74_row3_col6, #T_0da74_row3_col10, #T_0da74_row3_col12, #T_0da74_row3_col21, #T_0da74_row3_col24, #T_0da74_row4_col4, #T_0da74_row4_col5, #T_0da74_row4_col6, #T_0da74_row4_col11, #T_0da74_row4_col20, #T_0da74_row4_col23 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0da74_row0_col4 {
#   background-color: #fca588;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0da74_row0_col9 {
#   background-color: #fca486;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0da74_row0_col11 {
#   background-color: #e32f27;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0da74_row1_col0 {
#   background-color: #ffece3;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0da74_row1_col3 {
#   background-color: #e83429;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0da74_row1_col4, #T_0da74_row3_col4 {
#   background-color: #fcbea5;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0da74_row1_col7 {
#   background-color: #be151a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0da74_row2_col3 {
#   background-color: #a60f15;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0da74_row2_col7 {
#   background-color: #fca98c;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0da74_row2_col9 {
#   background-color: #b01217;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0da74_row3_col0, #T_0da74_row4_col10 {
#   background-color: #fb694a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0da74_row3_col7 {
#   background-color: #9d0d14;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0da74_row3_col11 {
#   background-color: #fca082;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_0da74_row4_col0 {
#   background-color: #f6553c;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0da74_row4_col3 {
#   background-color: #f5523a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_0da74_row4_col9 {
#   background-color: #f0402f;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_0da74_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >age</th>
#       <th class="col_heading level0 col1" >sex</th>
#       <th class="col_heading level0 col2" >cp</th>
#       <th class="col_heading level0 col3" >trestbps</th>
#       <th class="col_heading level0 col4" >chol</th>
#       <th class="col_heading level0 col5" >fbs</th>
#       <th class="col_heading level0 col6" >restecg</th>
#       <th class="col_heading level0 col7" >thalach</th>
#       <th class="col_heading level0 col8" >exang</th>
#       <th class="col_heading level0 col9" >oldpeak</th>
#       <th class="col_heading level0 col10" >slope</th>
#       <th class="col_heading level0 col11" >ca</th>
#       <th class="col_heading level0 col12" >thal</th>
#       <th class="col_heading level0 col13" >target</th>
#       <th class="col_heading level0 col14" >cp_0</th>
#       <th class="col_heading level0 col15" >cp_1</th>
#       <th class="col_heading level0 col16" >cp_2</th>
#       <th class="col_heading level0 col17" >cp_3</th>
#       <th class="col_heading level0 col18" >thal_0</th>
#       <th class="col_heading level0 col19" >thal_1</th>
#       <th class="col_heading level0 col20" >thal_2</th>
#       <th class="col_heading level0 col21" >thal_3</th>
#       <th class="col_heading level0 col22" >slope_0</th>
#       <th class="col_heading level0 col23" >slope_1</th>
#       <th class="col_heading level0 col24" >slope_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0da74_row0_col0" class="data row0 col0" >52</td>
#       <td id="T_0da74_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_0da74_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_0da74_row0_col3" class="data row0 col3" >125</td>
#       <td id="T_0da74_row0_col4" class="data row0 col4" >212</td>
#       <td id="T_0da74_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_0da74_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_0da74_row0_col7" class="data row0 col7" >168</td>
#       <td id="T_0da74_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_0da74_row0_col9" class="data row0 col9" >1.000000</td>
#       <td id="T_0da74_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_0da74_row0_col11" class="data row0 col11" >2</td>
#       <td id="T_0da74_row0_col12" class="data row0 col12" >3</td>
#       <td id="T_0da74_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_0da74_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_0da74_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_0da74_row0_col16" class="data row0 col16" >0</td>
#       <td id="T_0da74_row0_col17" class="data row0 col17" >0</td>
#       <td id="T_0da74_row0_col18" class="data row0 col18" >0</td>
#       <td id="T_0da74_row0_col19" class="data row0 col19" >0</td>
#       <td id="T_0da74_row0_col20" class="data row0 col20" >0</td>
#       <td id="T_0da74_row0_col21" class="data row0 col21" >1</td>
#       <td id="T_0da74_row0_col22" class="data row0 col22" >0</td>
#       <td id="T_0da74_row0_col23" class="data row0 col23" >0</td>
#       <td id="T_0da74_row0_col24" class="data row0 col24" >1</td>
#     </tr>
#     <tr>
#       <td id="T_0da74_row1_col0" class="data row1 col0" >53</td>
#       <td id="T_0da74_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_0da74_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_0da74_row1_col3" class="data row1 col3" >140</td>
#       <td id="T_0da74_row1_col4" class="data row1 col4" >203</td>
#       <td id="T_0da74_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_0da74_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_0da74_row1_col7" class="data row1 col7" >155</td>
#       <td id="T_0da74_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_0da74_row1_col9" class="data row1 col9" >3.100000</td>
#       <td id="T_0da74_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_0da74_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_0da74_row1_col12" class="data row1 col12" >3</td>
#       <td id="T_0da74_row1_col13" class="data row1 col13" >0<

# %%
x = df.drop(['target'], axis=1)
y = df['target']

# %%
x = MinMaxScaler().fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=4)

# %%
SVMclassifier = SVC(kernel='linear', max_iter=100, C=10, probability=True)
SVMclassifier.fit(x_train, y_train)

y_pred_SVM = SVMclassifier.predict(x_test)

# %%
# --- SVM Accuracy ---
SVMAcc = accuracy_score(y_pred_SVM, y_test)
print('.:. Support Vector Machine Accuracy:'+'\033[1m {:.2f}%'.format(SVMAcc*100)+' .:.')

# --- SVM Classification Report ---
print('\n\033[1m'+'.: Classification Report'+'\033[0m')
print('*' * 25)
print(classification_report(y_test, y_pred_SVM))
# Out:
# .:. Support Vector Machine Accuracy: 78.78% .:.
#
# .: Classification Report
# *************************
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.79       206
#            1       0.78      0.79      0.79       204
#
#     accuracy                           0.79       410
#    macro avg       0.79      0.79      0.79       410
# weighted avg       0.79      0.79      0.79       410
